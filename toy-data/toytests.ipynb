# %%
import torch

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from livelossplot import PlotLosses
from sklearn.metrics import roc_auc_score

# %%
from toyfunctions import *

# %%
# 99% background, 1% signal

df = maketoydata(background_fraction=0.99, signal_fraction=0.01)
train(df, batch_size=16, learning_rate=0.0001, epochs=20)
# Out:
# acc per count
# 	training         	 (min:    0.658, max:    0.660, cur:    0.660)
# 	validation       	 (min:    0.660, max:    0.661, cur:    0.660)
# Loss
# 	training         	 (min:    0.636, max:    0.646, cur:    0.636)
# 	validation       	 (min:    0.639, max:    0.645, cur:    0.641)
# Epoch 19, Loss: 0.5147274136543274
# Epoch 19, Accuracy: 0.6596596596596597
#
# ----------------------------------------
#
# Average test loss: 0.6428 | Test accuracy: 0.659
#
# Test ROC-AUC for fully supervised signal/sb region classifier: 0.512  (0.5 = no separation, 1.0 = perfect)
# Test ROC-AUC for true background/stream labels: 0.981  (0.5 = no separation, 1.0 = perfect)
#
# Purity = 0.0
# Completeness = 0.0

# %%
# 95% background, 5% signal

df = maketoydata(background_fraction=0.95, signal_fraction=0.05)
train(df, batch_size=16, learning_rate=0.0001, epochs=20)
# Out:
# acc per count
# 	training         	 (min:    0.651, max:    0.682, cur:    0.681)
# 	validation       	 (min:    0.656, max:    0.701, cur:    0.697)
# Loss
# 	training         	 (min:    0.624, max:    0.645, cur:    0.624)
# 	validation       	 (min:    0.610, max:    0.629, cur:    0.611)
# Epoch 19, Loss: 0.5868657231330872
# Epoch 19, Accuracy: 0.6966966966966966
#
# ----------------------------------------
#
# Average test loss: 0.6174 | Test accuracy: 0.685
#
# Test ROC-AUC for fully supervised signal/sb region classifier: 0.572  (0.5 = no separation, 1.0 = perfect)
# Test ROC-AUC for true background/stream labels: 0.996  (0.5 = no separation, 1.0 = perfect)
#
# Purity = 0.7213114754098361
# Completeness = 0.9565217391304348

# %%
# 90% background, 10% signal

df = maketoydata(background_fraction=0.90, signal_fraction=0.10)
train(df, batch_size=16, learning_rate=0.0001, epochs=20)
# Out:
# acc per count
# 	training         	 (min:    0.663, max:    0.707, cur:    0.706)
# 	validation       	 (min:    0.712, max:    0.726, cur:    0.721)
# Loss
# 	training         	 (min:    0.601, max:    0.638, cur:    0.603)
# 	validation       	 (min:    0.584, max:    0.618, cur:    0.585)
# Epoch 19, Loss: 0.7191188335418701
# Epoch 19, Accuracy: 0.7207207207207207
#
# ----------------------------------------
#
# Average test loss: 0.6328 | Test accuracy: 0.681
#
# Test ROC-AUC for fully supervised signal/sb region classifier: 0.556  (0.5 = no separation, 1.0 = perfect)
# Test ROC-AUC for true background/stream labels: 0.997  (0.5 = no separation, 1.0 = perfect)
#
# Purity = 0.7927927927927928
# Completeness = 0.9887640449438202

# %%
# 80% background, 20% signal

df = maketoydata(background_fraction=0.80, signal_fraction=0.20)
train(df, batch_size=16, learning_rate=0.0001, epochs=20)
# Out:
# acc per count
# 	training         	 (min:    0.677, max:    0.723, cur:    0.722)
# 	validation       	 (min:    0.701, max:    0.715, cur:    0.710)
# Loss
# 	training         	 (min:    0.578, max:    0.631, cur:    0.579)
# 	validation       	 (min:    0.597, max:    0.618, cur:    0.597)
# Epoch 19, Loss: 0.40950900316238403
# Epoch 19, Accuracy: 0.7097097097097097
#
# ----------------------------------------
#
# Average test loss: 0.5995 | Test accuracy: 0.706
#
# Test ROC-AUC for fully supervised signal/sb region classifier: 0.664  (0.5 = no separation, 1.0 = perfect)
# Test ROC-AUC for true background/stream labels: 0.995  (0.5 = no separation, 1.0 = perfect)
#
# Purity = 0.914572864321608
# Completeness = 0.9837837837837838
