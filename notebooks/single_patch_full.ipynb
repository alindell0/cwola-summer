# %%
## notebook for patch0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../scripts')

from functions import *

# %%
df_patch0 = load_data(0)
plot_data(df_patch0)
# Out:
# Data for Patch 0
