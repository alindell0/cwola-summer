# %%
import sys
sys.path.append('../scripts')

from functions import *

# %%
df_patch0 = load_data(0)
# Out:
# Data for Patch 0

# %%
plot_data(df_patch0, save_folder = None)

# %% [markdown]
# ## Patch 0: signal/sideband defining parameter pmdec

# %%
scan_var = 'rotpmdec'

# %%
df_regions = signal_sideband(df_patch0, save_folder = None, pm_parameter=scan_var, 
                             sig_factor=1, sb_factor=3)
# Out:
# Signal parameter: Rotated and Centered Proper Motion (DEC) μ_λ
# Signal region factor = 1 and sideband region factor = 3
# Signal parameter median = -13.147
# Signal parameter standard deviation = 1.163
# Signal Region Range: [-14.310, -11.984]
# Sideband Region Range: [-16.636, -14.310) and (-11.984, -9.658]
# Signal Region has 51528 stars, 307 stream and 51221 background.
# Sideband Region has 118124 stars, 57 stream and 118067 background.
# Outer Region has 2021540 stars, 14 stream and 2021526 background.

# %%
df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
                             lr=0.001, patience=30, epochs=100, trainval_loops=3, 
                             save_folder=f'check0/results/{scan_var}', wandbproj=None)
# Out:
# Proper Motion Parameter: Rotated and Centered Proper Motion (DEC) μ_λ
# Using device: cuda
# -----------------------------------------------
#
# Test fold 0...
# Validation fold 1...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:27<00:00,  1.14it/s]
# Starting training loop 2
# Training loop 2:  50%|█████     | 50/100 [00:43<00:43,  1.15it/s]
# Early stopping at epoch 50 with average val_loss 0.6134653687477112
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 1 = 0.6128172278404236
# Test scores saved for test fold 0 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:25<00:00,  1.16it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Best validation loss for validation fold label 2 = 0.6120943427085876
# Test scores saved for test fold 0 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3:  92%|█████████▏| 92/100 [01:19<00:06,  1.16it/s]
# Early stopping at epoch 92 with average val_loss 0.612586498260498
# Best validation loss for validation fold label 3 = 0.6125978827476501
# Test scores saved for test fold 0 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 4 = 0.6118289828300476
# Test scores saved for test fold 0 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# -----------------------------------------------
#
# Test fold 1...
# Validation fold 0...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:25<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 0 = 0.6118549704551697
# Test scores saved for test fold 1 val fold 0.
# Validation fold 2...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 2 = 0.6120948791503906
# Test scores saved for test fold 1 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:25<00:00,  1.18it/s]
# Best validation loss for validation fold label 3 = 0.6124413013458252
# Test scores saved for test fold 1 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 4 = 0.611766517162323
# Test scores saved for test fold 1 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# -----------------------------------------------
#
# Test fold 2...
# Validation fold 0...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 0 = 0.6121445894241333
# Test scores saved for test fold 2 val fold 0.
# Validation fold 1...
# Starting training loop 1
# Training loop 1:  92%|█████████▏| 92/100 [01:19<00:06,  1.16it/s]
# Early stopping at epoch 92 with average val_loss 0.6128413677215576
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:25<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 1 = 0.6128584146499634
# Test scores saved for test fold 2 val fold 1.
# Validation fold 3...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3:  81%|████████  | 81/100 [01:09<00:16,  1.17it/s]
# Early stopping at epoch 81 with average val_loss 0.6134185194969177
# Best validation loss for validation fold label 3 = 0.6131352186203003
# Test scores saved for test fold 2 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 4 = 0.611990213394165
# Test scores saved for test fold 2 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# -----------------------------------------------
#
# Test fold 3...
# Validation fold 0...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 0 = 0.6120527982711792
# Test scores saved for test fold 3 val fold 0.
# Validation fold 1...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:23<00:00,  1.19it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 1 = 0.6124805808067322
# Test scores saved for test fold 3 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2:  67%|██████▋   | 67/100 [00:57<00:28,  1.16it/s]
# Early stopping at epoch 67 with average val_loss 0.6132150292396545
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 2 = 0.6119397878646851
# Test scores saved for test fold 3 val fold 2.
# Validation fold 4...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Best validation loss for validation fold label 4 = 0.6116440296173096
# Test scores saved for test fold 3 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# -----------------------------------------------
#
# Test fold 4...
# Validation fold 0...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Best validation loss for validation fold label 0 = 0.6116169691085815
# Test scores saved for test fold 4 val fold 0.
# Validation fold 1...
# Starting training loop 1
# Training loop 1:  53%|█████▎    | 53/100 [00:45<00:40,  1.16it/s]
# Early stopping at epoch 53 with average val_loss 0.6135648488998413
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Best validation loss for validation fold label 1 = 0.6124601364135742
# Test scores saved for test fold 4 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Best validation loss for validation fold label 2 = 0.6119780540466309
# Test scores saved for test fold 4 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [01:24<00:00,  1.18it/s]
# Starting training loop 3
# Training loop 3: 100%|██████████| 100/100 [01:24<00:00,  1.19it/s]
# Best validation loss for validation fold label 3 = 0.6128659844398499
# Test scores saved for test fold 4 val fold 3.
# Averaging nn_scores for each star from the 4 best models...
# Full test df with all stars saved!

# %%
get_results(df_test_full, top_n=250, fid_cuts=True, save_folder=f'check0/results/{scan_var}', patch_idx=0)
# Out:
# Plotting after fiducial cuts...
# Top 250 ranked stars: Purity = 77.20%
# Top 250 ranked stars: Completeness = 65.20%

# %% [markdown]
# ## Patch 0: signal/sideband defining parameter pmra

# %%
scan_var = 'rotpmra'

# %%
df_regions = signal_sideband(df_patch0, save_folder = None, pm_parameter=scan_var, 
                             sig_factor=1, sb_factor=3)
# Out:
# Signal parameter: Rotated and Centered Proper Motion (RA) μ_ϕcosλ
# Signal region factor = 1 and sideband region factor = 3
# Signal parameter median = -2.912
# Signal parameter standard deviation = 0.943
# Signal Region Range: [-3.856, -1.969]
# Sideband Region Range: [-5.743, -3.856) and (-1.969, -0.082]
# Signal Region has 363129 stars, 261 stream and 362868 background.
# Sideband Region has 776360 stars, 117 stream and 776243 background.
# Outer Region has 1051703 stars, 0 stream and 1051703 background.

# %%
df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
                             lr=0.001, patience=30, epochs=100, trainval_loops=3, 
                             save_folder=f'check0/results/{scan_var}', wandbproj=None)
# Out:
# Proper Motion Parameter: Rotated and Centered Proper Motion (RA) μ_ϕcosλ
# Using device: cuda
# -----------------------------------------------
#
# Test fold 0...
# Validation fold 1...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [09:27<00:00,  5.68s/it]
# Starting training loop 2
# Training loop 2:  95%|█████████▌| 95/100 [09:04<00:28,  5.73s/it]
# Early stopping at epoch 95 with average val_loss 0.6116477251052856
# Starting training loop 3
# Training loop 3:  87%|████████▋ | 87/100 [08:17<01:14,  5.72s/it]
# Early stopping at epoch 87 with average val_loss 0.6116811037063599
# Best validation loss for validation fold label 1 = 0.6117008328437805
# Test scores saved for test fold 0 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1: 100%|██████████| 100/100 [09:25<00:00,  5.65s/it]
# Starting training loop 2
# Training loop 2: 100%|██████████| 100/100 [09:26<00:00,  5.66s/it]
# Starting training loop 3
# Training loop 3:  96%|█████████▌| 96/100 [09:08<00:22,  5.72s/it]
# Early stopping at epoch 96 with average val_loss 0.6120914816856384
# Best validation loss for validation fold label 2 = 0.6119968295097351
# Test scores saved for test fold 0 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 2:  88%|████████▊ | 88/100 [08:24<01:08,  5.73s/it]
# Early stopping at epoch 88 with average val_loss 0.6109944581985474
# Starting training loop 3
# Training loop 3:  78%|███████▊  | 78/100 [07:27<02:06,  5.74s/it]
# Early stopping at epoch 78 with average val_loss 0.6110529899597168
# Best validation loss for validation fold label 3 = 0.6109358668327332
# Test scores saved for test fold 0 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1:  12%|█▏        | 12/100 [01:08<08:20,  5.68s/it]

# %%
get_results(df_test_full, top_n=250, fid_cuts=True, save_folder=f'check0/results/{scan_var}', patch_idx=0)
