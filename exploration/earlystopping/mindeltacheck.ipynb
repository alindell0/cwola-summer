# %%
import sys
sys.path.append('../scripts')

from functions import *

# %%
scan_var = 'rotpmdec'

# %%
df_patch0 = load_data(0)
# Out:
# Data for Patch 0

# %% [markdown]
# ### min_delta = 0.0001

# %%
plot_data(df_patch0, save_folder = f'check0/data/{scan_var}')

# %%
df_regions = signal_sideband(df_patch0, save_folder = f'check0/results/{scan_var}', pm_parameter=scan_var, 
                             sig_factor=1, sb_factor=3)
# Out:
# Signal parameter: Rotated and Centered Proper Motion (DEC) μ_λ
# Signal region factor = 1 and sideband region factor = 3
# Signal parameter median = -13.147
# Signal parameter standard deviation = 1.163
# Signal Region Range: [-14.310, -11.984]
# Sideband Region Range: [-16.636, -14.310) and (-11.984, -9.658]
# Signal Region has 51528 stars, 307 stream and 51221 background.
# Sideband Region has 118124 stars, 57 stream and 118067 background.
# Outer Region has 2021540 stars, 14 stream and 2021526 background.

# %%
df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
                             lr=0.001, patience=30, epochs=100, trainval_loops=3, 
                             save_folder=f'check0/results/{scan_var}', wandbproj='patch0_mindelta')
# Out:
# Proper Motion Parameter: Rotated and Centered Proper Motion (DEC) μ_λ
# Using device: cuda
# Test fold 0...
# Validation fold 1...
# Starting training loop 1
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /global/homes/a/alindell/.netrc.
# wandb: Currently logged in as: alindell (alindell-university-of-wisconsin-madison) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_151807-flbfasno</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/flbfasno' target="_blank">test_0_val_1_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/flbfasno' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/flbfasno</a>
# Training loop 1: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▂▅▅▄▆▆▆▅▆▆▇▆▇▆▇▆▇▆███</td></tr><tr><td>train_loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▄▅▄▅▇▆▆▇▇▇█▇██▇▇</td></tr><tr><td>val_loss</td><td>█▇▅▄▃▃▃▄▄▃▄▂▂▂▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▁▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.6972</td></tr><tr><td>train_loss</td><td>0.61057</td></tr><tr><td>val_acc</td><td>0.69674</td></tr><tr><td>val_loss</td><td>0.61289</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_1_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/flbfasno' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/flbfasno</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_151807-flbfasno/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152007-rrd51w8r</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rrd51w8r' target="_blank">test_0_val_1_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rrd51w8r' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rrd51w8r</a>
# Training loop 2: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▆▅▄▅▇▆███</td></tr><tr><td>train_loss</td><td>█▇▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆▆▃▆▆▆▆▆▆▅█▇▇</td></tr><tr><td>val_loss</td><td>█▄▄▄▄▃▃▃▄▅▄▂▂▄▄▄▃▂▂▃▄▄▃▃▄▃▃▂▂▂▂▂▁▂▂▂▁▁▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69721</td></tr><tr><td>train_loss</td><td>0.61108</td></tr><tr><td>val_acc</td><td>0.69662</td></tr><tr><td>val_loss</td><td>0.61299</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_1_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rrd51w8r' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rrd51w8r</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152007-rrd51w8r/logs</code>
# Starting training loop 3
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152143-77dgmjad</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/77dgmjad' target="_blank">test_0_val_1_train_2</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/77dgmjad' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/77dgmjad</a>
# Training loop 3:  46%|████▌     | 46/100 [00:43<00:51,  1.05it/s]
# Early stopping at epoch 46 with average val_loss 0.6138833165168762
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▁▁▁▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▂▂▂▁▁▁▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>46</td></tr><tr><td>train_acc</td><td>0.69627</td></tr><tr><td>train_loss</td><td>0.61264</td></tr><tr><td>val_acc</td><td>0.69627</td></tr><tr><td>val_loss</td><td>0.61388</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_1_train_2</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/77dgmjad' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/77dgmjad</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152143-77dgmjad/logs</code>
# Best validation loss for validation fold label 1 = 0.6135798692703247
# Test scores saved for test fold 0 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152231-nol3wpb9</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nol3wpb9' target="_blank">test_0_val_2_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nol3wpb9' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nol3wpb9</a>
# Training loop 1: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇</td></tr><tr><td>train_loss</td><td>█▆▅▅▅▅▅▄▅▄▄▄▄▄▄▃▃▃▃▃▂▃▂▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▄▆█</td></tr><tr><td>val_loss</td><td>█▅▆▅▅▅▅▄▄▄▄▄▃▃▄▄▄▄▃▃▄▃▃▂▃▂▂▂▂▃▂▃▁▂▁▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69658</td></tr><tr><td>train_loss</td><td>0.61132</td></tr><tr><td>val_acc</td><td>0.69767</td></tr><tr><td>val_loss</td><td>0.6129</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_2_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nol3wpb9' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nol3wpb9</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152231-nol3wpb9/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152406-tk99i7sn</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/tk99i7sn' target="_blank">test_0_val_2_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/tk99i7sn' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/tk99i7sn</a>
# Training loop 2:  77%|███████▋  | 77/100 [01:12<00:21,  1.06it/s]
# Early stopping at epoch 77 with average val_loss 0.6130271553993225
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▇▅▅▅▄▄▄▄▅▄▄▄▄▃▄▃▃▃▂▃▄▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▄▄▄▃▃▄▃▅▃▃▃▃▂▄▂▃▂▂▂▂▃▂▂▂▂▁▂▁▁▁▁▁▂▁▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>77</td></tr><tr><td>train_acc</td><td>0.69627</td></tr><tr><td>train_loss</td><td>0.61186</td></tr><tr><td>val_acc</td><td>0.69626</td></tr><tr><td>val_loss</td><td>0.61303</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_2_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/tk99i7sn' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/tk99i7sn</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152406-tk99i7sn/logs</code>
# Starting training loop 3
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152522-1t5bdwie</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/1t5bdwie' target="_blank">test_0_val_2_train_2</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/1t5bdwie' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/1t5bdwie</a>
# Training loop 3: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>train_loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▄▅▄▅▆▆▆▆▇▇▇█▇</td></tr><tr><td>val_loss</td><td>█▄▃▂▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▂▁▁▁▁▁▁▁▁▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.6969</td></tr><tr><td>train_loss</td><td>0.61095</td></tr><tr><td>val_acc</td><td>0.69747</td></tr><tr><td>val_loss</td><td>0.61198</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_2_train_2</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/1t5bdwie' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/1t5bdwie</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152522-1t5bdwie/logs</code>
# Best validation loss for validation fold label 2 = 0.6119205951690674
# Test scores saved for test fold 0 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152659-02silvp9</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/02silvp9' target="_blank">test_0_val_3_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/02silvp9' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/02silvp9</a>
# Training loop 1: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▄▄▅▅▆▅▆▆▆▅▆█</td></tr><tr><td>train_loss</td><td>█▆▆▅▄▄▄▄▄▄▄▄▄▃▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▄▅▄▅▅▆▅▆▆█▅██</td></tr><tr><td>val_loss</td><td>█▅▃▃▃▂▂▂▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.6973</td></tr><tr><td>train_loss</td><td>0.61093</td></tr><tr><td>val_acc</td><td>0.69714</td></tr><tr><td>val_loss</td><td>0.61248</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_3_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/02silvp9' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/02silvp9</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152659-02silvp9/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_152836-986leqdd</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/986leqdd' target="_blank">test_0_val_3_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/986leqdd' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/986leqdd</a>
# Training loop 2: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>██▆▆▆▅▅▄▅▅▄▄▄▄▄▄▄▄▃▃▃▃▄▃▃▃▃▃▂▂▃▂▂▁▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▅▅▅▅▄▇▇██▇█</td></tr><tr><td>val_loss</td><td>█▄▂▃▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69723</td></tr><tr><td>train_loss</td><td>0.61104</td></tr><tr><td>val_acc</td><td>0.69723</td></tr><tr><td>val_loss</td><td>0.61244</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_3_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/986leqdd' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/986leqdd</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_152836-986leqdd/logs</code>
# Starting training loop 3
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153012-zxq9cfec</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/zxq9cfec' target="_blank">test_0_val_3_train_2</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/zxq9cfec' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/zxq9cfec</a>
# Training loop 3: 100%|██████████| 100/100 [01:35<00:00,  1.04it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▄▄▄▄▅▄▄▅▅▅▆▅▆▅▆▇▇██▆</td></tr><tr><td>train_loss</td><td>█▆▆▅▅▄▅▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▃▃▆▇▃▅▆▆▆▇▇▇▇▇█▇▇▇</td></tr><tr><td>val_loss</td><td>▇█▆▅▅▄▄▃▃▄▇▅▄▄▃▃▃▄▃▃▄▂▂▂▂▂▂▂▂▂▁▁▂▁▁▂▁▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69727</td></tr><tr><td>train_loss</td><td>0.61033</td></tr><tr><td>val_acc</td><td>0.69717</td></tr><tr><td>val_loss</td><td>0.61229</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_3_train_2</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/zxq9cfec' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/zxq9cfec</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153012-zxq9cfec/logs</code>
# Best validation loss for validation fold label 3 = 0.6121810674667358
# Test scores saved for test fold 0 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153151-vezcyg1v</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vezcyg1v' target="_blank">test_0_val_4_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vezcyg1v' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vezcyg1v</a>
# Training loop 1: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train_acc</td><td>▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██▇█████</td></tr><tr><td>train_loss</td><td>█▆▅▅▄▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▂▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▇██▆█▆▇▆▇▄▇▆▅▅▇▆█▇▇▇</td></tr><tr><td>val_loss</td><td>█▆▅▅▄▅▄▄▄▄▄▄▄▄▃▅▄▃▃▃▂▄▃▃▂▃▂▁▂▂▂▁▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69721</td></tr><tr><td>train_loss</td><td>0.61045</td></tr><tr><td>val_acc</td><td>0.69717</td></tr><tr><td>val_loss</td><td>0.61196</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_4_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vezcyg1v' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vezcyg1v</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153151-vezcyg1v/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153328-amq7c0i1</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/amq7c0i1' target="_blank">test_0_val_4_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/amq7c0i1' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/amq7c0i1</a>
# Training loop 2: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▄▄▄▄▄▄▄▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▄▃▄▅▆▅▅▅▆▆▆▆▇▆▆▆▇▆█▇██▇█</td></tr><tr><td>train_loss</td><td>█▆▅▅▅▄▄▄▄▄▄▄▄▃▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▂▁▂▁▁▁▁</td></tr><tr><td>val_acc</td><td>▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▄▃▄▃▄▅▅▅▄▆▇▅▇▅▅▇▇▆█▆▇▆▆▆</td></tr><tr><td>val_loss</td><td>█▇▅▄▄▄▄▄▄▄▄▄▃▃▄▄▄▄▃▄▄▃▂▃▃▃▂▂▂▂▂▁▁▁▁▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69708</td></tr><tr><td>train_loss</td><td>0.6105</td></tr><tr><td>val_acc</td><td>0.69729</td></tr><tr><td>val_loss</td><td>0.61171</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_4_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/amq7c0i1' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/amq7c0i1</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153328-amq7c0i1/logs</code>
# Starting training loop 3
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153504-nrj89g69</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nrj89g69' target="_blank">test_0_val_4_train_2</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nrj89g69' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nrj89g69</a>
# Training loop 3: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▃▄▄▂▆▅▅▆▆▆▅▅▅▇▆█▇▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▅▆▆▅▆▆▅▆▅█▅██▆▇▅█▅</td></tr><tr><td>val_loss</td><td>█▃▂▃▃▂▃▃▃▂▂▃▂▂▂▂▂▂▂▂▁▂▁▁▂▁▁▁▂▁▁▁▁▁▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69712</td></tr><tr><td>train_loss</td><td>0.61072</td></tr><tr><td>val_acc</td><td>0.69747</td></tr><tr><td>val_loss</td><td>0.61172</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_4_train_2</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nrj89g69' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/nrj89g69</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153504-nrj89g69/logs</code>
# Best validation loss for validation fold label 4 = 0.6117753982543945
# Test scores saved for test fold 0 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# Test fold 1...
# Validation fold 0...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153641-0zvw6w9n</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/0zvw6w9n' target="_blank">test_1_val_0_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/0zvw6w9n' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/0zvw6w9n</a>
# Training loop 1: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▃▄▅▄▆▆▆▅▆▆▆█▆▇▆██▇▇▇▇</td></tr><tr><td>train_loss</td><td>█▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂▂▅▄▅▅▄▃▆▅▆▅▆▅▆▆▆▇▆▆▅██▇▇▇█▇</td></tr><tr><td>val_loss</td><td>█▇▄▄▄▄▄▄▄▃▃▄▃▃▃▃▃▃▂▃▃▄▅▂▃▂▂▁▂▁▁▁▁▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69748</td></tr><tr><td>train_loss</td><td>0.61009</td></tr><tr><td>val_acc</td><td>0.69703</td></tr><tr><td>val_loss</td><td>0.61187</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_0_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/0zvw6w9n' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/0zvw6w9n</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153641-0zvw6w9n/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153816-n4vpzwdd</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/n4vpzwdd' target="_blank">test_1_val_0_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/n4vpzwdd' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/n4vpzwdd</a>
# Training loop 2: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>train_loss</td><td>█▇▆▆▆▅▅▅▅▅▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄▁▂▅▅▆▅▆▆▅▅▄▆▄▇▇▇▇▇▆█</td></tr><tr><td>val_loss</td><td>█▆▅▅▅▅▅▄▇▆▅▄▄▄▄▃▃▃▅▄▃▃▃▂▂▂▂▃▂▂▂▂▂▂▁▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69727</td></tr><tr><td>train_loss</td><td>0.61018</td></tr><tr><td>val_acc</td><td>0.69697</td></tr><tr><td>val_loss</td><td>0.61202</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_0_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/n4vpzwdd' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/n4vpzwdd</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153816-n4vpzwdd/logs</code>
# Starting training loop 3
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_153952-8nclna8t</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/8nclna8t' target="_blank">test_1_val_0_train_2</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/8nclna8t' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/8nclna8t</a>
# Training loop 3: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▄▄▄▄▄▃▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▄▅▅▆▆▆▆▆▇▅▆▆▄▅▆▅█▅▆█▃▅▆▇</td></tr><tr><td>val_loss</td><td>█▄▄▃▃▃▃▃▃▃▃▃▃▃▃▄▂▃▃▃▃▂▃▂▂▂▁▂▂▂▁▂▁▂▂▁▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69715</td></tr><tr><td>train_loss</td><td>0.61053</td></tr><tr><td>val_acc</td><td>0.69665</td></tr><tr><td>val_loss</td><td>0.61203</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_0_train_2</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/8nclna8t' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/8nclna8t</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_153952-8nclna8t/logs</code>
# Best validation loss for validation fold label 0 = 0.6118082404136658
# Test scores saved for test fold 1 val fold 0.
# Validation fold 2...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_154128-00mwr98t</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/00mwr98t' target="_blank">test_1_val_2_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/00mwr98t' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/00mwr98t</a>
# Training loop 1: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▃▃▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▂▃▂▂▂▂▂▂▂▂▁▂▂▂▂▂▁▁▂▁▁▁▂▂▁▁▁▁▁▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.6963</td></tr><tr><td>train_loss</td><td>0.61106</td></tr><tr><td>val_acc</td><td>0.69626</td></tr><tr><td>val_loss</td><td>0.6128</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_2_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/00mwr98t' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/00mwr98t</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_154128-00mwr98t/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# ...
# Find logs at: <code>./wandb/run-20260804_154926-ujjmkbi9/logs</code>
# Best validation loss for validation fold label 3 = 0.6121607422828674
# Test scores saved for test fold 1 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_155101-rq0apfmy</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rq0apfmy' target="_blank">test_1_val_4_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rq0apfmy' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rq0apfmy</a>
# Training loop 1: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▃▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▂▃▅▃▅▄▅▅▅▇▇█▇▆▇██</td></tr><tr><td>train_loss</td><td>█▆▆▆▆▅▅▆▆▅▅▄▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▁▁</td></tr><tr><td>val_acc</td><td>▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▃▃▇▇▆▇█▇▇▇██▆▇▇▇▇█▇▇</td></tr><tr><td>val_loss</td><td>██▄▄▄▄▄▃▄▆▃▃▃▃▄▄▄▃▅▄▃▂▂▃▃▂▂▁▂▃▂▁▁▁▁▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69684</td></tr><tr><td>train_loss</td><td>0.61051</td></tr><tr><td>val_acc</td><td>0.6972</td></tr><tr><td>val_loss</td><td>0.61212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_4_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rq0apfmy' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/rq0apfmy</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_155101-rq0apfmy/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_155238-x4c8b7a4</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/x4c8b7a4' target="_blank">test_1_val_4_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/x4c8b7a4' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/x4c8b7a4</a>
# Training loop 2: 100%|██████████| 100/100 [01:33<00:00,  1.07it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train_acc</td><td>▁▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▆▅▆▆▆▇▇▇▆▇▆▇▇████▇▇▇█</td></tr><tr><td>train_loss</td><td>█▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▅▆▅▆▆▇▆▇▆▇▇▇▆▆▇▆█▆▇█████</td></tr><tr><td>val_loss</td><td>█▆▅▆▅▅▅▅▆▄▅▄▅▅▄▄▄▆▄▄▃▃▃▃▃▂▃▂▂▂▂▂▁▂▁▁▃▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69721</td></tr><tr><td>train_loss</td><td>0.60963</td></tr><tr><td>val_acc</td><td>0.69749</td></tr><tr><td>val_loss</td><td>0.61166</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_4_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/x4c8b7a4' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/x4c8b7a4</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_155238-x4c8b7a4/logs</code>
# Starting training loop 3
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_155414-k17s53qi</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/k17s53qi' target="_blank">test_1_val_4_train_2</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/k17s53qi' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/k17s53qi</a>
# Training loop 3: 100%|██████████| 100/100 [01:32<00:00,  1.08it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇███</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▅▄▅▅▆▅▆▅▇▆▅▆▆▇▆█▇▇██</td></tr><tr><td>train_loss</td><td>█▅▅▄▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▂▂▂▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▆▅▆▅▆▇▇▆▇▇▅█▇█▇</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▂▂▂▂▃▂▃▂▂▂▃▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69714</td></tr><tr><td>train_loss</td><td>0.61017</td></tr><tr><td>val_acc</td><td>0.69732</td></tr><tr><td>val_loss</td><td>0.61205</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_1_val_4_train_2</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/k17s53qi' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/k17s53qi</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_155414-k17s53qi/logs</code>
# Best validation loss for validation fold label 4 = 0.6116992831230164
# Test scores saved for test fold 1 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# Test fold 2...
# Validation fold 0...
# Starting training loop 1
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_155550-ydci84zc</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/ydci84zc' target="_blank">test_2_val_0_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/ydci84zc' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/ydci84zc</a>
# Training loop 1: 100%|██████████| 100/100 [01:31<00:00,  1.09it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▂▃▄▄▅▆▆▇▆▆▇██████</td></tr><tr><td>train_loss</td><td>█▇█▇▇▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▃▄▃▂▃▂▂▁▂▂▂▂▂▁▂▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▃▅▆▆▇▇▄▇▅▇█</td></tr><tr><td>val_loss</td><td>█▇█▅▅▅▅▆▅▄▄▅▄▄▅▅▄▄▄▄▄▄▃▃▄▃▃▃▃▃▂▂▂▂▂▁▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_acc</td><td>0.69706</td></tr><tr><td>train_loss</td><td>0.61093</td></tr><tr><td>val_acc</td><td>0.69694</td></tr><tr><td>val_loss</td><td>0.61159</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_2_val_0_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/ydci84zc' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/ydci84zc</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_155550-ydci84zc/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_155725-vk07eix2</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vk07eix2' target="_blank">test_2_val_0_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vk07eix2' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vk07eix2</a>
# Training loop 2:  23%|██▎       | 23/100 [00:21<01:12,  1.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
#       2                              lr=0.001, patience=30, epochs=100, trainval_loops=3,
#       3                              save_folder=f'check0/results/{scan_var}', wandbproj='patch0_mindelta')
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/../scripts/functions.py:301, in cwola_train(df, pm_parameter, dropout, k_folds, batch_size, lr, patience, epochs, trainval_loops, save_folder, wandbproj)
#     298 train_correct = torch.tensor(0.0, device=device)
#     299 counts = 0
# --> 301 for inputs, region_labels in train_loader:
#     302     optimizer.zero_grad()
#     303     out = model(inputs).squeeze(1) # forward pass
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataset.py:211, in TensorDataset.__getitem__(self, index)
#     210 def __getitem__(self, index):
# --> 211     return tuple(tensor[index] for tensor in self.tensors)
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataset.py:211, in <genexpr>(.0)
#     210 def __getitem__(self, index):
# --> 211     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:

# %%
get_results(df_test_full, top_n=250, fid_cuts=True, save_folder=f'check0/results/{scan_var}', patch_idx=0)

# %% [markdown]
# ### min_delta = 0.001

# %%
def cwola_train(df, pm_parameter='rotpmdec', dropout=0.2, k_folds=5, batch_size=10000, lr=0.001, patience=30, epochs=100, trainval_loops=3, save_folder='../results/stream/patch', wandbproj='sim-1patch'):

    use_wandb = wandbproj is not None

    os.makedirs(save_folder, exist_ok=True)

    # denotes training variables, separate from proper motion parameter used to define signal/sideband regions
    if pm_parameter == 'rotpmdec':
        training_vars = ['b-r', 'g', 'rotra', 'rotdec', 'rotpmra']
        print('Proper Motion Parameter: Rotated and Centered Proper Motion (DEC) μ_λ')
    if pm_parameter == 'rotpmra':
        training_vars = ['b-r', 'g', 'rotra', 'rotdec', 'rotpmdec']
        print('Proper Motion Parameter: Rotated and Centered Proper Motion (RA) μ_ϕcosλ')

    # model architecture
    class NeuralNetwork(nn.Module):
        def __init__(self, input_dim = 5, hidden_dim = 256, output_dim = 1, dropout=dropout): # create tool, parameters for recalling, call function is used after
            super().__init__() # access all methods, attributes, etc of class
            self.NeuralNetwork = nn.Sequential(
                nn.Linear(input_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(p=dropout),       
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(p=dropout),       
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(p=dropout),       
                nn.Linear(hidden_dim, output_dim),
                nn.Sigmoid()
            )
        def forward(self, x):
            return self.NeuralNetwork(x)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f'Using device: {device}')

    # k-folding
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=18)

    fold_stars = [] # will become a list of k (5) arrays, representing the k folds
    for fold_idx, (train_index, test_index) in enumerate(skf.split(df[training_vars], df['region_label'])):
        fold_stars.append(test_index)
    fold_labels = np.arange(len(fold_stars)) # fold labels is an array of values 0-4, representing indices/labels of the 5 folds

    test_dfs = []
    for test_idx in fold_labels: # loops through each fold as the test fold
        print(f'Test fold {test_idx}...')
        
        test_stars = fold_stars[test_idx]
        save_folder_test = os.path.join(save_folder, "test_fold_{}".format(test_idx))
        os.makedirs(save_folder_test, exist_ok=True)

        for val_idx in np.delete(fold_labels, test_idx): # cycles through remaining sets (minus the test set) for validation sets
            print(f'Validation fold {val_idx}...')
            val_stars = fold_stars[val_idx]
    
            train_indices = np.delete(fold_labels, [test_idx, val_idx])
            train_stars = np.concatenate([fold_stars[train_idx] for train_idx in train_indices])
    
            df_train = df.iloc[train_stars] # create data frames with indices
            df_val = df.iloc[val_stars]
            df_test = df.iloc[test_stars]
    
            train_x = df_train[training_vars]
            train_y = df_train['region_label'].to_numpy()
    
            val_x = df_val[training_vars]
            val_y = df_val['region_label'].to_numpy()
    
            test_x = df_test[training_vars]
            test_y = df_test['region_label'].to_numpy()
            test_y_true = df_test['stream'].to_numpy(dtype=int)

            scaler = StandardScaler() # scale data to standardize with mean of 0 and standard deviation of 1
            
            train_x = scaler.fit_transform(train_x) # fit_transform called only on train data
            val_x = scaler.transform(val_x)
            test_x = scaler.transform(test_x)
                    
            # create tensors, datasets, and loaders
            train_x_tensor = torch.tensor(np.array(train_x), dtype=torch.float32, device=device)
            train_y_tensor = torch.tensor(train_y, dtype=torch.float32, device=device)
                
            val_x_tensor = torch.tensor(np.array(val_x), dtype=torch.float32, device=device)
            val_y_tensor = torch.tensor(val_y, dtype=torch.float32, device=device)
                
            test_x_tensor = torch.tensor(np.array(test_x), dtype=torch.float32, device=device)
            test_y_tensor = torch.tensor(test_y, dtype=torch.float32, device=device)
            test_y_true_tensor = torch.tensor(test_y_true, dtype=torch.long, device=device)
                
            train_dataset = TensorDataset(train_x_tensor, train_y_tensor)
            val_dataset = TensorDataset(val_x_tensor, val_y_tensor)
            test_dataset = TensorDataset(test_x_tensor, test_y_tensor, test_y_true_tensor)
                
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
            test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

            best_loop_val_loss = float('inf')

            test_nn_scores = []
            
            for n in range(trainval_loops): # trains the model trainval_loops number of times (equal to the number of remaining folds, used as training)
                print(f'Starting training loop {n+1}')

                if use_wandb:
                    run = wandb.init(project=wandbproj,
                                group=f"fold_{test_idx}",
                                job_type=f"val_set_{val_idx}",
                                name=f"test_{test_idx}_val_{val_idx}_train_{n}",
                                config={"test_fold": test_idx, "val_set": val_idx, "train_loop": n},
                                reinit=True)
                    
                # initialize model upon each training loop
                model = NeuralNetwork(input_dim = 5, hidden_dim = 256, output_dim = 1, dropout=dropout).to(device)
                loss_fn = nn.BCELoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
                best_val_loss = float('inf')
                patience_counter = 0
                
                for epoch in tqdm(range(epochs), desc=f"Training loop {n+1}"):
                
                    # training
                    model.train()
                    total_train_loss = torch.tensor(0.0, device=device)
                    train_correct = torch.tensor(0.0, device=device)
                    counts = 0
                    
                    for inputs, region_labels in train_loader:
                        optimizer.zero_grad()
                        out = model(inputs).squeeze(1) # forward pass
                        loss = loss_fn(out, region_labels) # compute loss
                        loss.backward()
                        optimizer.step()
                        total_train_loss += loss.detach() * inputs.size(0)
                    
                        predictions = (out > 0.5).float()
                        train_correct += (predictions == region_labels).sum()
                        counts += region_labels.size(0)
                    
                    avg_train_loss = (total_train_loss / counts).item()  
                    train_accuracy = (train_correct / counts).item()
                    
                    # validation, used to track loss/accuracy, monitor for early stopping
                    model.eval()
                    total_val_loss = torch.tensor(0.0, device=device)
                    val_correct = torch.tensor(0.0, device=device)
                    counts = 0
                    with torch.no_grad():
                        for inputs, region_labels in val_loader:
                            out = model(inputs).squeeze(1)
                            loss = loss_fn(out, region_labels)
                            total_val_loss += loss.detach() * inputs.size(0)
                    
                            predictions = (out > 0.5).float()
                            val_correct += (predictions == region_labels).sum()
                            counts += region_labels.size(0)
                
                    avg_val_loss = (total_val_loss / counts).item()
                    val_accuracy = (val_correct / counts).item()

                    if use_wandb:
                        wandb.log({"train_loss": avg_train_loss, "val_loss": avg_val_loss,
                                 "train_acc": train_accuracy, "val_acc": val_accuracy, "epoch": epoch})

                    # early stopping
                    if avg_val_loss < best_val_loss - 0.001:
                        best_val_loss = avg_val_loss
                        patience_counter = 0
                        best_model = copy.deepcopy(model.state_dict())
                    else:
                        patience_counter += 1
                
                    if patience_counter >= patience:
                        print(f"Early stopping at epoch {epoch} with average val_loss {best_val_loss}")
                        break
                
                if best_val_loss < best_loop_val_loss:
                    best_loop_val_loss = best_val_loss
                    lowest_val_loss_model = best_model ## model parameters from epoch with the lowest validation loss

                if use_wandb:
                    run.finish()
                    
            print(f'Best validation loss for validation fold label {val_idx} = {best_loop_val_loss}')
            model_save_path = os.path.join(save_folder_test, "val_set_{}_best_model".format(val_idx))
            torch.save(lowest_val_loss_model, model_save_path) ## model parameters from training run with the lowest validation loss

            model.load_state_dict(lowest_val_loss_model) ## test set evaluated on the best model from each of the 4 validation sets

            model.eval()
            test_loss, test_correct, counts = 0.0, 0.0, 0
            raw_scores = []
            
            with torch.no_grad():
                for inputs, region_labels, true_labels in test_loader:
                    out = model(inputs).squeeze()
                    raw_scores.extend(out.squeeze().cpu().numpy())
                    # loss = loss_fn(out, region_labels)
                    # test_loss += loss.item() * inputs.size(0)
                    # scores = (out > 0.5).float()
                    # test_correct += (scores == region_labels).sum().item()
                    # counts += region_labels.size(0)
            
            test_nn_scores.append(raw_scores)
            print(f'Test scores saved for test fold {test_idx} val fold {val_idx}.')

        print('Averaging nn_scores for each star from the 4 best models...')
        df_test['nn_score'] = np.mean(test_nn_scores, axis=0)
        test_dfs.append(df_test)

    df_test_full = pd.concat([df for df in test_dfs])
    out_path = f'{save_folder}/df_test.h5'
    df_test_full.to_hdf(out_path, key='data', mode='w')
    print('Full test df with all stars saved!')

    return df_test_full

# %%
df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
                             lr=0.001, patience=30, epochs=100, trainval_loops=3, 
                             save_folder=f'check0/results/mindelta_001', wandbproj=None)
# Out:
# Proper Motion Parameter: Rotated and Centered Proper Motion (DEC) μ_λ
# Using device: cuda
# Test fold 0...
# Validation fold 1...
# Starting training loop 1
# Training loop 1:  40%|████      | 40/100 [00:38<00:57,  1.05it/s]
# Early stopping at epoch 40 with average val_loss 0.6135913133621216
# Starting training loop 2
# Training loop 2:  34%|███▍      | 34/100 [00:32<01:02,  1.06it/s]
# Early stopping at epoch 34 with average val_loss 0.6141522526741028
# Starting training loop 3
# Training loop 3:  46%|████▌     | 46/100 [00:43<00:50,  1.06it/s]
# Early stopping at epoch 46 with average val_loss 0.6136255264282227
# Best validation loss for validation fold label 1 = 0.6135913133621216
# Test scores saved for test fold 0 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1:  40%|████      | 40/100 [00:37<00:56,  1.05it/s]
# Early stopping at epoch 40 with average val_loss 0.6138123273849487
# Starting training loop 2
# Training loop 2:  54%|█████▍    | 54/100 [00:50<00:43,  1.06it/s]
# Early stopping at epoch 54 with average val_loss 0.6135438084602356
# Starting training loop 3
# Training loop 3:  41%|████      | 41/100 [00:39<00:56,  1.05it/s]
# Early stopping at epoch 41 with average val_loss 0.6137142777442932
# Best validation loss for validation fold label 2 = 0.6135438084602356
# Test scores saved for test fold 0 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 1:  37%|███▋      | 37/100 [00:35<01:00,  1.05it/s]
# Early stopping at epoch 37 with average val_loss 0.6143247485160828
# Starting training loop 2
# Training loop 2:  37%|███▋      | 37/100 [00:35<00:59,  1.05it/s]
# Early stopping at epoch 37 with average val_loss 0.6140354871749878
# Starting training loop 3
# Training loop 3:  37%|███▋      | 37/100 [00:35<01:00,  1.05it/s]
# Early stopping at epoch 37 with average val_loss 0.6141373515129089
# Best validation loss for validation fold label 3 = 0.6140354871749878
# Test scores saved for test fold 0 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6140199303627014
# Starting training loop 2
# Training loop 2:  35%|███▌      | 35/100 [00:33<01:01,  1.05it/s]
# Early stopping at epoch 35 with average val_loss 0.6139957308769226
# Starting training loop 3
# Training loop 3:  35%|███▌      | 35/100 [00:33<01:02,  1.05it/s]
# Early stopping at epoch 35 with average val_loss 0.6141655445098877
# Best validation loss for validation fold label 4 = 0.6139957308769226
# Test scores saved for test fold 0 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# Test fold 1...
# Validation fold 0...
# Starting training loop 1
# Training loop 1:  40%|████      | 40/100 [00:37<00:56,  1.06it/s]
# Early stopping at epoch 40 with average val_loss 0.6135308146476746
# Starting training loop 2
# Training loop 2:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6139364242553711
# Starting training loop 3
# Training loop 3:  41%|████      | 41/100 [00:38<00:55,  1.06it/s]
# Early stopping at epoch 41 with average val_loss 0.6135552525520325
# Best validation loss for validation fold label 0 = 0.6135308146476746
# Test scores saved for test fold 1 val fold 0.
# Validation fold 2...
# Starting training loop 1
# Training loop 1:  36%|███▌      | 36/100 [00:34<01:00,  1.06it/s]
# Early stopping at epoch 36 with average val_loss 0.6138240694999695
# Starting training loop 2
# Training loop 2:  38%|███▊      | 38/100 [00:36<00:58,  1.05it/s]
# Early stopping at epoch 38 with average val_loss 0.6136489510536194
# Starting training loop 3
# Training loop 3:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6141894459724426
# Best validation loss for validation fold label 2 = 0.6136489510536194
# Test scores saved for test fold 1 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 1:  36%|███▌      | 36/100 [00:34<01:00,  1.05it/s]
# Early stopping at epoch 36 with average val_loss 0.6142674088478088
# Starting training loop 2
# Training loop 2:  60%|██████    | 60/100 [00:56<00:37,  1.07it/s]
# Early stopping at epoch 60 with average val_loss 0.6135467290878296
# Starting training loop 3
# Training loop 3:  36%|███▌      | 36/100 [00:34<01:00,  1.06it/s]
# Early stopping at epoch 36 with average val_loss 0.6142351627349854
# Best validation loss for validation fold label 3 = 0.6135467290878296
# Test scores saved for test fold 1 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6139135956764221
# Starting training loop 2
# Training loop 2:  39%|███▉      | 39/100 [00:37<00:57,  1.05it/s]
# Early stopping at epoch 39 with average val_loss 0.613702118396759
# Starting training loop 3
# Training loop 3:  49%|████▉     | 49/100 [00:46<00:48,  1.06it/s]
# Early stopping at epoch 49 with average val_loss 0.6131805181503296
# Best validation loss for validation fold label 4 = 0.6131805181503296
# Test scores saved for test fold 1 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# Test fold 2...
# Validation fold 0...
# Starting training loop 1
# Training loop 1:  46%|████▌     | 46/100 [00:43<00:50,  1.06it/s]
# Early stopping at epoch 46 with average val_loss 0.6132829785346985
# Starting training loop 2
# Training loop 2:  34%|███▍      | 34/100 [00:32<01:02,  1.06it/s]
# Early stopping at epoch 34 with average val_loss 0.6138983964920044
# Starting training loop 3
# Training loop 3:  36%|███▌      | 36/100 [00:34<01:00,  1.06it/s]
# Early stopping at epoch 36 with average val_loss 0.6135309934616089
# Best validation loss for validation fold label 0 = 0.6132829785346985
# Test scores saved for test fold 2 val fold 0.
# Validation fold 1...
# Starting training loop 1
# Training loop 1:  35%|███▌      | 35/100 [00:33<01:02,  1.05it/s]
# Early stopping at epoch 35 with average val_loss 0.6137909293174744
# Starting training loop 2
# Training loop 2:  41%|████      | 41/100 [00:38<00:55,  1.06it/s]
# Early stopping at epoch 41 with average val_loss 0.6135584712028503
# Starting training loop 3
# Training loop 3:  36%|███▌      | 36/100 [00:34<01:00,  1.05it/s]
# Early stopping at epoch 36 with average val_loss 0.6136412620544434
# Best validation loss for validation fold label 1 = 0.6135584712028503
# Test scores saved for test fold 2 val fold 1.
# Validation fold 3...
# Starting training loop 1
# Training loop 1:  37%|███▋      | 37/100 [00:35<00:59,  1.05it/s]
# Early stopping at epoch 37 with average val_loss 0.6141351461410522
# Starting training loop 2
# Training loop 2:  35%|███▌      | 35/100 [00:33<01:02,  1.05it/s]
# Early stopping at epoch 35 with average val_loss 0.6141694188117981
# Starting training loop 3
# Training loop 3:  38%|███▊      | 38/100 [00:35<00:58,  1.06it/s]
# Early stopping at epoch 38 with average val_loss 0.6140551567077637
# Best validation loss for validation fold label 3 = 0.6140551567077637
# Test scores saved for test fold 2 val fold 3.
# Validation fold 4...
# Starting training loop 1
# Training loop 1:  56%|█████▌    | 56/100 [00:52<00:41,  1.07it/s]
# Early stopping at epoch 56 with average val_loss 0.6135075688362122
# Starting training loop 2
# Training loop 2:  46%|████▌     | 46/100 [00:43<00:50,  1.06it/s]
# Early stopping at epoch 46 with average val_loss 0.6132473945617676
# Starting training loop 3
# Training loop 3:  58%|█████▊    | 58/100 [00:54<00:39,  1.07it/s]
# Early stopping at epoch 58 with average val_loss 0.612930178642273
# Best validation loss for validation fold label 4 = 0.612930178642273
# Test scores saved for test fold 2 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# Test fold 3...
# Validation fold 0...
# Starting training loop 1
# Training loop 1:  38%|███▊      | 38/100 [00:35<00:58,  1.06it/s]
# Early stopping at epoch 38 with average val_loss 0.6133621335029602
# Starting training loop 2
# Training loop 2:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6137418746948242
# Starting training loop 3
# Training loop 3:  35%|███▌      | 35/100 [00:33<01:01,  1.06it/s]
# Early stopping at epoch 35 with average val_loss 0.6137993931770325
# Best validation loss for validation fold label 0 = 0.6133621335029602
# Test scores saved for test fold 3 val fold 0.
# Validation fold 1...
# Starting training loop 1
# Training loop 1:  40%|████      | 40/100 [00:37<00:56,  1.06it/s]
# Early stopping at epoch 40 with average val_loss 0.6136243939399719
# Starting training loop 2
# Training loop 2:  39%|███▉      | 39/100 [00:36<00:57,  1.06it/s]
# Early stopping at epoch 39 with average val_loss 0.6136026382446289
# Starting training loop 3
# Training loop 3:  34%|███▍      | 34/100 [00:32<01:03,  1.04it/s]
# Early stopping at epoch 34 with average val_loss 0.6140771508216858
# Best validation loss for validation fold label 1 = 0.6136026382446289
# Test scores saved for test fold 3 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1:  36%|███▌      | 36/100 [00:34<01:00,  1.05it/s]
# Early stopping at epoch 36 with average val_loss 0.613787055015564
# Starting training loop 2
# Training loop 2:  45%|████▌     | 45/100 [00:42<00:52,  1.06it/s]
# Early stopping at epoch 45 with average val_loss 0.6134433150291443
# Starting training loop 3
# Training loop 3:  37%|███▋      | 37/100 [00:35<01:00,  1.04it/s]
# Early stopping at epoch 37 with average val_loss 0.6138466596603394
# Best validation loss for validation fold label 2 = 0.6134433150291443
# Test scores saved for test fold 3 val fold 2.
# Validation fold 4...
# Starting training loop 1
# Training loop 1:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6137803792953491
# Starting training loop 2
# Training loop 2:  45%|████▌     | 45/100 [00:42<00:51,  1.06it/s]
# Early stopping at epoch 45 with average val_loss 0.6132776737213135
# Starting training loop 3
# Training loop 3:  36%|███▌      | 36/100 [00:34<01:00,  1.05it/s]
# Early stopping at epoch 36 with average val_loss 0.613847553730011
# Best validation loss for validation fold label 4 = 0.6132776737213135
# Test scores saved for test fold 3 val fold 4.
# Averaging nn_scores for each star from the 4 best models...
# Test fold 4...
# Validation fold 0...
# Starting training loop 1
# Training loop 1:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6137878894805908
# Starting training loop 2
# Training loop 2:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6138018369674683
# Starting training loop 3
# Training loop 3:  35%|███▌      | 35/100 [00:33<01:02,  1.04it/s]
# Early stopping at epoch 35 with average val_loss 0.613972008228302
# Best validation loss for validation fold label 0 = 0.6137878894805908
# Test scores saved for test fold 4 val fold 0.
# Validation fold 1...
# Starting training loop 1
# Training loop 1:  41%|████      | 41/100 [00:39<00:56,  1.05it/s]
# Early stopping at epoch 41 with average val_loss 0.6136429309844971
# Starting training loop 2
# Training loop 2:  36%|███▌      | 36/100 [00:34<01:00,  1.05it/s]
# Early stopping at epoch 36 with average val_loss 0.6137176752090454
# Starting training loop 3
# Training loop 3:  35%|███▌      | 35/100 [00:33<01:01,  1.06it/s]
# Early stopping at epoch 35 with average val_loss 0.6138187646865845
# Best validation loss for validation fold label 1 = 0.6136429309844971
# Test scores saved for test fold 4 val fold 1.
# Validation fold 2...
# Starting training loop 1
# Training loop 1:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6141542792320251
# Starting training loop 2
# Training loop 2:  56%|█████▌    | 56/100 [00:52<00:41,  1.07it/s]
# Early stopping at epoch 56 with average val_loss 0.6133139729499817
# Starting training loop 3
# Training loop 3:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6143109202384949
# Best validation loss for validation fold label 2 = 0.6133139729499817
# Test scores saved for test fold 4 val fold 2.
# Validation fold 3...
# Starting training loop 1
# Training loop 1:  41%|████      | 41/100 [00:38<00:55,  1.05it/s]
# Early stopping at epoch 41 with average val_loss 0.6139141917228699
# Starting training loop 2
# Training loop 2:  34%|███▍      | 34/100 [00:32<01:02,  1.05it/s]
# Early stopping at epoch 34 with average val_loss 0.6145097017288208
# Starting training loop 3
# Training loop 3:  64%|██████▍   | 64/100 [00:59<00:33,  1.07it/s]
# Early stopping at epoch 64 with average val_loss 0.6135283708572388
# Best validation loss for validation fold label 3 = 0.6135283708572388
# Test scores saved for test fold 4 val fold 3.
# Averaging nn_scores for each star from the 4 best models...
# Full test df with all stars saved!

# %%
get_results(df_test_full, top_n=250, fid_cuts=True, save_folder=f'check0/results/{scan_var}/mindelta_001', patch_idx=0)
# Out:
# Plotting after fiducial cuts...
# Top 250 ranked stars: Purity = 18.40%
# Top 250 ranked stars: Completeness = 15.54%

# %% [markdown]
# ### find convergence point with min_delta=0

# %%
def cwola_train(df, pm_parameter='rotpmdec', dropout=0.2, k_folds=5, batch_size=10000, lr=0.001, patience=30, epochs=100, trainval_loops=3, save_folder='../results/stream/patch', wandbproj='sim-1patch'):

    use_wandb = wandbproj is not None

    os.makedirs(save_folder, exist_ok=True)

    # denotes training variables, separate from proper motion parameter used to define signal/sideband regions
    if pm_parameter == 'rotpmdec':
        training_vars = ['b-r', 'g', 'rotra', 'rotdec', 'rotpmra']
        print('Proper Motion Parameter: Rotated and Centered Proper Motion (DEC) μ_λ')
    if pm_parameter == 'rotpmra':
        training_vars = ['b-r', 'g', 'rotra', 'rotdec', 'rotpmdec']
        print('Proper Motion Parameter: Rotated and Centered Proper Motion (RA) μ_ϕcosλ')

    # model architecture
    class NeuralNetwork(nn.Module):
        def __init__(self, input_dim = 5, hidden_dim = 256, output_dim = 1, dropout=dropout): # create tool, parameters for recalling, call function is used after
            super().__init__() # access all methods, attributes, etc of class
            self.NeuralNetwork = nn.Sequential(
                nn.Linear(input_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(p=dropout),       
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(p=dropout),       
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Dropout(p=dropout),       
                nn.Linear(hidden_dim, output_dim),
                nn.Sigmoid()
            )
        def forward(self, x):
            return self.NeuralNetwork(x)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f'Using device: {device}')

    # k-folding
    skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=18)

    fold_stars = [] # will become a list of k (5) arrays, representing the k folds
    for fold_idx, (train_index, test_index) in enumerate(skf.split(df[training_vars], df['region_label'])):
        fold_stars.append(test_index)
    fold_labels = np.arange(len(fold_stars)) # fold labels is an array of values 0-4, representing indices/labels of the 5 folds

    test_dfs = []
    for test_idx in fold_labels: # loops through each fold as the test fold
        print('-----------------------------------------------')
        print(' ')
        print(f'Test fold {test_idx}...')
        
        test_stars = fold_stars[test_idx]
        save_folder_test = os.path.join(save_folder, "test_fold_{}".format(test_idx))
        os.makedirs(save_folder_test, exist_ok=True)

        for val_idx in np.delete(fold_labels, test_idx): # cycles through remaining sets (minus the test set) for validation sets
            print(f'Validation fold {val_idx}...')
            val_stars = fold_stars[val_idx]
    
            train_indices = np.delete(fold_labels, [test_idx, val_idx])
            train_stars = np.concatenate([fold_stars[train_idx] for train_idx in train_indices])
    
            df_train = df.iloc[train_stars] # create data frames with indices
            df_val = df.iloc[val_stars]
            df_test = df.iloc[test_stars]
    
            train_x = df_train[training_vars]
            train_y = df_train['region_label'].to_numpy()
    
            val_x = df_val[training_vars]
            val_y = df_val['region_label'].to_numpy()
    
            test_x = df_test[training_vars]
            test_y = df_test['region_label'].to_numpy()
            test_y_true = df_test['stream'].to_numpy(dtype=int)

            scaler = StandardScaler() # scale data to standardize with mean of 0 and standard deviation of 1
            
            train_x = scaler.fit_transform(train_x) # fit_transform called only on train data
            val_x = scaler.transform(val_x)
            test_x = scaler.transform(test_x)
                    
            # create tensors, datasets, and loaders
            train_x_tensor = torch.tensor(np.array(train_x), dtype=torch.float32, device=device)
            train_y_tensor = torch.tensor(train_y, dtype=torch.float32, device=device)
                
            val_x_tensor = torch.tensor(np.array(val_x), dtype=torch.float32, device=device)
            val_y_tensor = torch.tensor(val_y, dtype=torch.float32, device=device)
                
            test_x_tensor = torch.tensor(np.array(test_x), dtype=torch.float32, device=device)
            test_y_tensor = torch.tensor(test_y, dtype=torch.float32, device=device)
            test_y_true_tensor = torch.tensor(test_y_true, dtype=torch.long, device=device)
                
            train_dataset = TensorDataset(train_x_tensor, train_y_tensor)
            val_dataset = TensorDataset(val_x_tensor, val_y_tensor)
            test_dataset = TensorDataset(test_x_tensor, test_y_tensor, test_y_true_tensor)
                
            train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
            test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

            best_loop_val_loss = float('inf')

            test_nn_scores = []
            
            for n in range(trainval_loops): # trains the model trainval_loops number of times (equal to the number of remaining folds, used as training)
                print(f'Starting training loop {n+1}')

                if use_wandb:
                    run = wandb.init(project=wandbproj,
                                group=f"fold_{test_idx}",
                                job_type=f"val_set_{val_idx}",
                                name=f"test_{test_idx}_val_{val_idx}_train_{n}",
                                config={"test_fold": test_idx, "val_set": val_idx, "train_loop": n},
                                reinit=True)
                    
                # initialize model upon each training loop
                model = NeuralNetwork(input_dim = 5, hidden_dim = 256, output_dim = 1, dropout=dropout).to(device)
                loss_fn = nn.BCELoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
                best_val_loss = float('inf')
                patience_counter = 0
                
                for epoch in tqdm(range(epochs), desc=f"Training loop {n+1}"):
                
                    # training
                    model.train()
                    total_train_loss = torch.tensor(0.0, device=device)
                    train_correct = torch.tensor(0.0, device=device)
                    counts = 0
                    
                    for inputs, region_labels in train_loader:
                        optimizer.zero_grad()
                        out = model(inputs).squeeze(1) # forward pass
                        loss = loss_fn(out, region_labels) # compute loss
                        loss.backward()
                        optimizer.step()
                        total_train_loss += loss.detach() * inputs.size(0)
                    
                        predictions = (out > 0.5).float()
                        train_correct += (predictions == region_labels).sum()
                        counts += region_labels.size(0)
                    
                    avg_train_loss = (total_train_loss / counts).item()  
                    train_accuracy = (train_correct / counts).item()
                    
                    # validation, used to track loss/accuracy, monitor for early stopping
                    model.eval()
                    total_val_loss = torch.tensor(0.0, device=device)
                    val_correct = torch.tensor(0.0, device=device)
                    counts = 0
                    with torch.no_grad():
                        for inputs, region_labels in val_loader:
                            out = model(inputs).squeeze(1)
                            loss = loss_fn(out, region_labels)
                            total_val_loss += loss.detach() * inputs.size(0)
                    
                            predictions = (out > 0.5).float()
                            val_correct += (predictions == region_labels).sum()
                            counts += region_labels.size(0)
                
                    avg_val_loss = (total_val_loss / counts).item()
                    val_accuracy = (val_correct / counts).item()

                    if use_wandb:
                        wandb.log({"train_loss": avg_train_loss, "val_loss": avg_val_loss,
                                 "train_acc": train_accuracy, "val_acc": val_accuracy, "epoch": epoch})

                    # early stopping
                    if avg_val_loss < best_val_loss:
                        best_val_loss = avg_val_loss
                        patience_counter = 0
                        best_model = copy.deepcopy(model.state_dict())
                    else:
                        patience_counter += 1
                
                    if patience_counter >= patience:
                        print(f"Early stopping at epoch {epoch} with average val_loss {best_val_loss}")
                        break

                print(f"Stopping at epoch {epoch} with average val_loss {best_val_loss}")
                if best_val_loss < best_loop_val_loss:
                    best_loop_val_loss = best_val_loss
                    lowest_val_loss_model = best_model ## model parameters from epoch with the lowest validation loss

                if use_wandb:
                    run.finish()
                    
            print(f'Best validation loss for validation fold label {val_idx} = {best_loop_val_loss}')
            model_save_path = os.path.join(save_folder_test, "val_set_{}_best_model".format(val_idx))
            torch.save(lowest_val_loss_model, model_save_path) ## model parameters from training run with the lowest validation loss

            model.load_state_dict(lowest_val_loss_model) ## test set evaluated on the best model from each of the 4 validation sets

            model.eval()
            test_loss, test_correct, counts = 0.0, 0.0, 0
            raw_scores = []
            
            with torch.no_grad():
                for inputs, region_labels, true_labels in test_loader:
                    out = model(inputs).squeeze()
                    raw_scores.extend(out.squeeze().cpu().numpy())
                    # loss = loss_fn(out, region_labels)
                    # test_loss += loss.item() * inputs.size(0)
                    # scores = (out > 0.5).float()
                    # test_correct += (scores == region_labels).sum().item()
                    # counts += region_labels.size(0)
            
            test_nn_scores.append(raw_scores)
            print(f'Test scores saved for test fold {test_idx} val fold {val_idx}.')

        print('Averaging nn_scores for each star from the 4 best models...')
        df_test['nn_score'] = np.mean(test_nn_scores, axis=0)
        test_dfs.append(df_test)

    df_test_full = pd.concat([df for df in test_dfs])
    out_path = f'{save_folder}/df_test.h5'
    df_test_full.to_hdf(out_path, key='data', mode='w')
    print('Full test df with all stars saved!')

    return df_test_full

# %%
df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
                             lr=0.001, patience=30, epochs=300, trainval_loops=3, 
                             save_folder=f'check0/results/epochs500', wandbproj='check0_epochs500')

### end early, see just a few runs and val levels
# Out:
# Proper Motion Parameter: Rotated and Centered Proper Motion (DEC) μ_λ
# Using device: cuda
# -----------------------------------------------
#
# Test fold 0...
# Validation fold 1...
# Starting training loop 1
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>train_acc</td><td>▁██████████████████████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>22</td></tr><tr><td>train_acc</td><td>0.69628</td></tr><tr><td>train_loss</td><td>0.61361</td></tr><tr><td>val_acc</td><td>0.69627</td></tr><tr><td>val_loss</td><td>0.61349</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_2_val_0_train_1</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vk07eix2' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta/runs/vk07eix2</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/patch0_mindelta</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_155725-vk07eix2/logs</code>
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_164817-eac9gutg</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/eac9gutg' target="_blank">test_0_val_1_train_0</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/eac9gutg' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/eac9gutg</a>
# Training loop 1:  35%|███▍      | 104/300 [01:40<03:09,  1.03it/s]
# Early stopping at epoch 104 with average val_loss 0.6125739812850952
# Stopping at epoch 104 with average val_loss 0.6125739812850952
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train_acc</td><td>▁███████████████████████████████████████</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▃▃▄▅▆▅▆▆▆▆█▆▇▇▇▇▇▇▇█▇▇</td></tr><tr><td>val_loss</td><td>█▃▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>104</td></tr><tr><td>train_acc</td><td>0.69743</td></tr><tr><td>train_loss</td><td>0.60991</td></tr><tr><td>val_acc</td><td>0.69686</td></tr><tr><td>val_loss</td><td>0.61301</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">test_0_val_1_train_0</strong> at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/eac9gutg' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/eac9gutg</a><br> View project at: <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260804_164817-eac9gutg/logs</code>
# Starting training loop 2
# Tracking run with wandb version 0.28.1
# Run data is saved locally in <code>/global/cfs/cdirs/m4474/alindell/cwola-summer/notebooks/wandb/run-20260804_165008-n7xazib1</code>
# Syncing run <strong><a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/n7xazib1' target="_blank">test_0_val_1_train_1</a></strong> to <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500</a>
#  View run at <a href='https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/n7xazib1' target="_blank">https://wandb.ai/alindell-university-of-wisconsin-madison/check0_epochs500/runs/n7xazib1</a>
# Training loop 2:  10%|█         | 31/300 [00:31<04:35,  1.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_test_full = cwola_train(df_regions, pm_parameter=scan_var, dropout=0.2, k_folds=5, batch_size=10000,
#       2                              lr=0.001, patience=30, epochs=300, trainval_loops=3,
#       3                              save_folder=f'check0/results/epochs500', wandbproj='check0_epochs500')
#       4
#
# Cell In[14], line 133, in cwola_train(df, pm_parameter, dropout, k_folds, batch_size, lr, patience, epochs, trainval_loops, save_folder, wandbproj)
#     129                     total_train_loss = torch.tensor(0.0, device=device)
#     130                     train_correct = torch.tensor(0.0, device=device)
#     131                     counts = 0
#     132
# --> 133                     for inputs, region_labels in train_loader:
#     134                         optimizer.zero_grad()
#     135                         out = model(inputs).squeeze(1) # forward pass
#     136                         loss = loss_fn(out, region_labels) # compute loss
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataset.py:211, in TensorDataset.__getitem__(self, index)
#     210 def __getitem__(self, index):
# --> 211     return tuple(tensor[index] for tensor in self.tensors)
#
# File /global/cfs/cdirs/m4474/alindell/cwola-summer/.venv/lib/python3.13/site-packages/torch/utils/data/dataset.py:211, in <genexpr>(.0)
#     210 def __getitem__(self, index):
# --> 211     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:
